# %% [markdown]
# <a href="https://colab.research.google.com/github/anushka10079/EDArepo/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataframe = pd.read_csv("https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Medicaid1986.csv")

# %%
#top 10 values
dataframe.head(10)
# Out:
#    rownames  visits  exposure  children  age  income  health1  health2  \
# 0         1       0       100         1   24  14.500    0.495   -0.854
# 1         2       1        90         3   19   6.000    0.520   -0.969
# 2         3       0       106         4   17   8.377   -1.227    0.317
# 3         4       0       114         2   29   6.000   -1.524    0.457
# 4         5      11       115         1   26   8.500    0.173   -0.599
# 5         6       3       102         1   22   6.000   -0.905    0.062
# 6         7       0        92         2   24   4.000   -1.202    0.202
# 7         8       6        92         1   21   6.000    0.656   -0.981
# 8         9       1       117         1   21   6.000   -1.227    0.317
# 9        10       0       101         1   24   6.000   -0.235   -0.562
#
#    access married  gender ethnicity  school enroll program
# 0    0.50      no  female      cauc      13    yes    afdc
# 1    0.17      no  female      cauc      11    yes    afdc
# ...

# %%
#last 10 values
dataframe.tail(10)
# Out:
#      rownames  visits  exposure  children  age  income  health1  health2  \
# 986       987       2        98         0   68   4.000   -2.113    0.236
# 987       988       2       114         0   66   8.500   -0.404   -0.876
# 988       989       4       114         0   87   6.000    0.416    0.810
# 989       990      12       114         0   78   8.500    1.822    0.298
# 990       991       0       117         0   67  11.500   -0.209   -0.122
# 991       992       0       106         0   65   8.500   -2.264    0.347
# 992       993       1       107         0   90   9.660    1.532    0.455
# 993       994      10       116         1   70   6.000    2.660   -0.723
# 994       995       3       118         0   73   6.000    0.813    0.056
# 995       996       0       115         2   71  10.444   -2.113    0.236
#
#      access married  gender ethnicity  school enroll program
# 986    0.33      no    male      cauc      10     no     ssi
# ...

# %%
dataframe.shape
# Out:
# (996, 15)

# %%
#Finding no of entries in exposure column
dataframe['exposure'].value_counts()
# Out:
# exposure
# 106    54
# 101    53
# 107    53
# 100    52
# 99     50
# 113    47
# 114    42
# 97     40
# 110    39
# 90     38
# 103    38
# 93     37
# 116    36
# 102    36
# 115    34
# 109    31
# 98     30
# 108    30
# 92     29
# 96     26
# 91     23
# 105    23
# 118    23
# 120    21
# 111    20
# 104    18
# 117    15
# 94     15
# 119    11
# 95     11
# 112     8
# 89      7
# 39      1
# 32      1
# 52      1
# 69      1
# 86      1
# 71      1
# Name: count, dtype: int64

# %%
#Finding no of entries in income column
dataframe['income'].value_counts()
# Out:
# income
# 6.000     363
# 8.500     236
# 11.500    107
# 17.500     69
# 4.000      65
# 14.500     34
# 2.500      19
# 7.993      11
# 1.500      10
# 0.500       8
# 7.218       5
# 8.377       4
# 9.782       4
# 7.250       4
# 7.990       4
# 7.839       3
# 9.875       3
# 10.264      3
# 8.250       3
# 7.140       3
# 7.040       3
# 8.554       3
# 7.831       3
# 7.950       2
# 10.750      2
# 6.931       2
# 8.114       2
# 10.204      2
# 6.180       2
# 9.660       2
# 12.150      1
# 12.262      1
# 6.375       1
# 8.950       1
# 9.643       1
# 9.642       1
# 9.963       1
# 7.562       1
# 9.578       1
# 13.375      1
# 8.375       1
# 7.150       1
# 6.850       1
# 7.152       1
# 10.444      1
# Name: count, dtype: int64

# %%
#Using describe function for dataset

dataframe.describe()
# Out:
#          rownames      visits    exposure    children         age      income  \
# count  996.000000  996.000000  996.000000  996.000000  996.000000  996.000000
# mean   498.500000    1.930723  104.060241    1.314257   55.205823    8.191302
# std    287.664735    3.354472    9.144973    1.509314   24.961373    3.630549
# min      1.000000    0.000000   32.000000    0.000000   16.000000    0.500000
# 25%    249.750000    0.000000   98.000000    0.000000   29.000000    6.000000
# 50%    498.500000    1.000000  104.000000    1.000000   66.000000    7.990000
# 75%    747.250000    3.000000  111.000000    2.000000   78.000000    8.500000
# max    996.000000   50.000000  120.000000    9.000000  105.000000   17.500000
#
#           health1     health2      access      school
# count  996.000000  996.000000  996.000000  996.000000
# mean    -0.000013    0.000020    0.398102    9.029116
# std      1.436934    0.740226    0.184439    4.353957
# ...

# %%
#Reshaping with Hierarchical Indexing
stacked = dataframe.stack()
stacked
# Out:
# 0    rownames         1
#      visits           0
#      exposure       100
#      children         1
#      age             24
#                   ...
# 995  gender        male
#      ethnicity    other
#      school          14
#      enroll          no
#      program        ssi
# Length: 14940, dtype: object

# %%
#Using the unstack function for the above stacked Data
stacked.unstack()
# Out:
#     rownames visits exposure children age  income health1 health2 access  \
# 0          1      0      100        1  24    14.5   0.495  -0.854    0.5
# 1          2      1       90        3  19     6.0    0.52  -0.969   0.17
# 2          3      0      106        4  17   8.377  -1.227   0.317   0.42
# 3          4      0      114        2  29     6.0  -1.524   0.457   0.33
# 4          5     11      115        1  26     8.5   0.173  -0.599   0.67
# ..       ...    ...      ...      ...  ..     ...     ...     ...    ...
# 991      992      0      106        0  65     8.5  -2.264   0.347   0.33
# 992      993      1      107        0  90    9.66   1.532   0.455    0.5
# 993      994     10      116        1  70     6.0    2.66  -0.723   0.17
# 994      995      3      118        0  73     6.0   0.813   0.056   0.17
# 995      996      0      115        2  71  10.444  -2.113   0.236   0.42
#
#     married  gender ethnicity school enroll program
# ...

# %%
#Checking for Duplicated Data
dataframe.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 991    False
# 992    False
# 993    False
# 994    False
# 995    False
# Length: 996, dtype: bool

# %%
#Checking fir null values
dataframe.isnull()
# Out:
#      rownames  visits  exposure  children    age  income  health1  health2  \
# 0       False   False     False     False  False   False    False    False
# 1       False   False     False     False  False   False    False    False
# 2       False   False     False     False  False   False    False    False
# 3       False   False     False     False  False   False    False    False
# 4       False   False     False     False  False   False    False    False
# ..        ...     ...       ...       ...    ...     ...      ...      ...
# 991     False   False     False     False  False   False    False    False
# 992     False   False     False     False  False   False    False    False
# 993     False   False     False     False  False   False    False    False
# 994     False   False     False     False  False   False    False    False
# 995     False   False     False     False  False   False    False    False
#
#      access  married  gender  ethnicity  school  enroll  program
# ...

# %%
# We can use the sum() method to count the number of NaN values in each store.
dataframe.isnull().sum()
# Out:
# rownames     0
# visits       0
# exposure     0
# children     0
# age          0
# income       0
# health1      0
# health2      0
# access       0
# married      0
# gender       0
# ethnicity    0
# school       0
# enroll       0
# program      0
# dtype: int64

# %%
#We can go one level deeper to find the total number of missing values
dataframe.isnull().sum().sum()
# Out:
# 0

# %%
#No of values in the dataset
dataframe.count()
# Out:
# rownames     996
# visits       996
# exposure     996
# children     996
# age          996
# income       996
# health1      996
# health2      996
# access       996
# married      996
# gender       996
# ethnicity    996
# school       996
# enroll       996
# program      996
# dtype: int64

# %%
#Finding sum of column health1 in dataset
hel1 = dataframe.health1
hel1.sum()
# Out:
# -0.012999999999994571

# %%
#Finding mean of health1 in dataset
hel1.mean()
# Out:
# -1.3052208835335916e-05

# %%
#finding cumsum of health1 in dataset
hel1.cumsum()
# Out:
# 0      0.495
# 1      1.015
# 2     -0.212
# 3     -1.736
# 4     -1.563
#        ...
# 991   -2.905
# 992   -1.373
# 993    1.287
# 994    2.100
# 995   -0.013
# Name: health1, Length: 996, dtype: float64

# %%
#Finding sum of column income in dataset
incc = dataframe.income
incc.sum()
# Out:
# 8158.537

# %%
#Finding mean of income in dataset
incc.mean()
# Out:
# 0    6.0
# Name: income, dtype: float64

# %%
#Finding median of income in dataset
incc.median()
# Out:
# 7.99

# %%
#Finding mode of income in dataset
incc.mode()
# Out:
# 0    6.0
# Name: income, dtype: float64

# %%
#finding cumsum of income in dataset
incc.cumsum()
# Out:
# 0        14.500
# 1        20.500
# 2        28.877
# 3        34.877
# 4        43.377
#          ...
# 991    8126.433
# 992    8136.093
# 993    8142.093
# 994    8148.093
# 995    8158.537
# Name: income, Length: 996, dtype: float64

# %%
#Finding income  that exceeded 8:
dataframe[np.abs(dataframe.income) > 8]
# Out:
#      rownames  visits  exposure  children  age  income  health1  health2  \
# 0           1       0       100         1   24  14.500    0.495   -0.854
# 2           3       0       106         4   17   8.377   -1.227    0.317
# 4           5      11       115         1   26   8.500    0.173   -0.599
# 17         18       1       111         1   30   8.500   -0.285   -0.332
# 20         21       0       110         4   42   8.500    0.581   -0.637
# ..        ...     ...       ...       ...  ...     ...      ...      ...
# 989       990      12       114         0   78   8.500    1.822    0.298
# 990       991       0       117         0   67  11.500   -0.209   -0.122
# 991       992       0       106         0   65   8.500   -2.264    0.347
# 992       993       1       107         0   90   9.660    1.532    0.455
# 995       996       0       115         2   71  10.444   -2.113    0.236
#
#      access married  gender ethnicity  school enroll program
# ...

# %%
pd.get_dummies(dataframe['ethnicity'])
# Out:
#       cauc  other
# 0     True  False
# 1     True  False
# 2     True  False
# 3     True  False
# 4     True  False
# ..     ...    ...
# 991   True  False
# 992   True  False
# 993   True  False
# 994   True  False
# 995  False   True
#
# [996 rows x 2 columns]

# %%
#Checking datatype of each column
dataframe.dtypes
# Out:
# rownames       int64
# visits         int64
# exposure       int64
# children       int64
# age            int64
# income       float64
# health1      float64
# health2      float64
# access       float64
# married       object
# gender        object
# ethnicity     object
# school         int64
# enroll        object
# program       object
# dtype: object

# %% [markdown]
# Univariate Analysis

# %%
#Distribution Plot for age
sns.FacetGrid(dataframe).map(sns.distplot, "age").add_legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
#Distribution Plot for exposure
sns.FacetGrid(dataframe).map(sns.distplot, "exposure").add_legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
#Boxplot for income
sns.boxplot(x="income", data=dataframe)
plt.show()

# %%
#Boxplot for access
sns.boxplot(x="access", data=dataframe)
plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
#Scatter Plot
#Plot the relationship between health1 and health2
plt.scatter(dataframe["health1"], dataframe["health2"])
plt.title("Scatter Plot for Health1 vs Health2")
plt.xlabel("health1")
plt.ylabel("health2")
# Out:
# Text(0, 0.5, 'health2')

# %%
#Scatter Plot
#Plot the relationship between age and access
plt.scatter(dataframe["age"], dataframe["access"])
plt.title("Scatter Plot for age vs access")
plt.xlabel("age")
plt.ylabel("access")
# Out:
# Text(0, 0.5, 'access')

# %%
#Boxplot between children and income
sns.boxplot(x="children", y="income", data=dataframe)
plt.show()

# %%
#Boxplot between visits and exposure
sns.boxplot(x="visits", y="exposure", data=dataframe)
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
# pair plot with plot type regression between income, heath1 and health2
sns.pairplot(dataframe,vars = ['income', 'health1','health2'],
kind="reg")
plt.show()

# %%
# pair plot with plot type regression between income, children and age
sns.pairplot(dataframe,vars = ['income', 'children','age'],
kind="reg")
plt.show()

# %%
#pair plot (matrix scatterplot) of age, health1, health2
sns.set(style="ticks", color_codes=True)
sns.pairplot(dataframe,vars = ['age', 'health1','health2'], hue="income")
plt.show()

# %%
#pair plot (matrix scatterplot) of exposure, access, agae
sns.set(style="ticks", color_codes=True)
sns.pairplot(dataframe,vars = ['exposure', 'access','age'], hue="income")
plt.show()

# %%
#calculate the correlation coefficient for the income and age
from scipy import stats
corr = stats.pearsonr(dataframe["income"], dataframe["age"])
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 0.3070284931410801
# cor:		 0.0323989255348873

# %%
#calculate the correlation coefficient for the heath1 and heath2
from scipy import stats
corr = stats.pearsonr(dataframe["health1"], dataframe["health2"])
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 0.999679919736576
# cor:		 -1.2727259018044726e-05

# %%
#To find the correlation among the entire numerical records the columns using pearson method
df_encodedd = pd.get_dummies(dataframe, drop_first=True)
correlationn= df_encodedd.corr(method='pearson')
correlationn
# Out:
#                  rownames    visits  exposure  children       age    income  \
# rownames         1.000000  0.083851  0.002930 -0.499293  0.814434  0.026087
# visits           0.083851  1.000000  0.065726 -0.112417  0.095161  0.001245
# exposure         0.002930  0.065726  1.000000  0.008748  0.010521 -0.004037
# children        -0.499293 -0.112417  0.008748  1.000000 -0.580759  0.245881
# age              0.814434  0.095161  0.010521 -0.580759  1.000000  0.032399
# income           0.026087  0.001245 -0.004037  0.245881  0.032399  1.000000
# health1          0.017332  0.268702 -0.011497 -0.018190  0.081452 -0.001627
# health2         -0.027534  0.001618 -0.037039 -0.021553  0.053305  0.021525
# access          -0.013392  0.029433  0.014523 -0.080460  0.085041  0.002390
# school          -0.358652  0.009566  0.041957  0.036229 -0.368781 -0.118488
# married_yes      0.168782 -0.023279  0.018121 -0.004650  0.134127  0.203679
# ...

# %%
#. Visualize the above  correlation  using a heatmap.
sns.heatmap(correlationn,xticklabels=correlationn.columns,
            yticklabels=correlationn.columns)
# Out:
# <Axes: >

# %% [markdown]
# Time Series Analysis

# %%
#Using  the seaborn library to plot the time series data.
plt.figure(figsize=(16, 8))
g = sns.lineplot(data=dataframe.access)
g.set_title('Zero mean model')
g.set_xlabel('Time index')
plt.show()

# %%
#performing  a cumulative sum over the list and then plot the data using a time series plot.
random_walk = np.cumsum(dataframe.health1)
random_walk
# Out:
# 0      0.495
# 1      1.015
# 2     -0.212
# 3     -1.736
# 4     -1.563
#        ...
# 991   -2.905
# 992   -1.373
# 993    1.287
# 994    2.100
# 995   -0.013
# Name: health1, Length: 996, dtype: float64

# %%
# plotting  the list using the time series plot to shows the change in values over time:
plt.figure(figsize=(16, 8))
g = sns.lineplot(data=random_walk)
g.set_title('Random Walk')
g.set_xlabel('Time index')
plt.show()

# %%
#displaying  five random rows from the dataframe:

dataframe.sample(5, random_state=0)
# Out:
#      rownames  visits  exposure  children  age  income  health1  health2  \
# 983       984       0        91         2   75   6.000    0.617   -0.699
# 724       725       4        99         1   83  17.500    2.843   -0.282
# 31         32       0       106         4   34   6.000   -1.041    0.075
# 995       996       0       115         2   71  10.444   -2.113    0.236
# 864       865       4       116         0   75   6.000   -0.928   -0.521
#
#      access married  gender ethnicity  school enroll program
# 983    0.25     yes    male     other       3     no     ssi
# 724    0.50      no  female      cauc      14    yes     ssi
# 31     0.50      no  female      cauc      12    yes    afdc
# 995    0.42     yes    male     other      14     no     ssi
# 864    0.42      no  female      cauc      12     no     ssi

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11, 4)}) #Runtime Configuration
plt.rcParams['figure.figsize'] = (8,5)
plt.rcParams['figure.dpi'] = 150


#2. Next, let's generate a line plot of the full time series of Germany's daily electricity consumption:
dataframe['health1'].plot(linewidth=0.25)
# Out:
# <Axes: >

# %%
#3. Let's use the dots to plot the data for all the other columns:
cols_to_plot = ['income', 'exposure', 'age']
axes = dataframe[cols_to_plot].plot(marker='.', alpha=0.5,
linestyle='None',figsize=(14, 6), subplots=True)   #True for subplots

# %%
fig, axes = plt.subplots(3, 1, figsize=(8, 7), sharex=True)
for name, ax in zip(['health1', 'health2', 'exposure'], axes):
  sns.boxplot(data=dataframe, x='age', y=name, ax=ax)
  ax.set_title(name)
  if ax != axes[-1]:
    ax.set_xlabel('')

# %% [markdown]
# 1D Statistical Data
# Analysis

# %%
#calculating median for income
dataframe.income.median()
# Out:
# 7.99

# %%
#calculating arithmetic mean for age
dataframe.age.mean()
# Out:
# 55.20582329317269

# %%
#calculating geometric mean for income
np.exp(np.mean(np.log(dataframe.income)))
# Out:
# 7.384891775599752

# %%
#calculating harmonic mean for exposure
1 / np.mean(1/dataframe.exposure)
# Out:
# 103.04683516746982

# %%
#calculating mode for income
dataframe.income.mode()
# Out:
# 0    6.0
# Name: income, dtype: float64

# %%
#calculating quartiles for income
np.quantile(dataframe.income, [0.25, 0.5, 0.75])
# Out:
# array([6.  , 7.99, 8.5 ])

# %%
#calculating deciles for exposure
np.quantile(dataframe.exposure, np.arange(0.1, 1.0, 0.1))
# Out:
# array([ 92.,  97.,  99., 101., 104., 107., 109., 113., 116.])

# %%
#calculating percentile for exposure
np.quantile(dataframe.exposure, np.arange(0.1, 1.0, 0.01))
# Out:
# array([ 92.  ,  93.  ,  93.  ,  93.  ,  93.3 ,  94.  ,  95.  ,  96.  ,
#         96.  ,  96.  ,  97.  ,  97.  ,  97.  ,  97.  ,  98.  ,  98.  ,
#         98.  ,  99.  ,  99.  ,  99.  ,  99.  ,  99.  , 100.  , 100.  ,
#        100.  , 100.  , 100.  , 101.  , 101.  , 101.  , 101.  , 101.  ,
#        102.  , 102.  , 102.  , 102.  , 103.  , 103.  , 103.  , 103.  ,
#        104.  , 104.  , 105.  , 105.  , 106.  , 106.  , 106.  , 106.  ,
#        106.  , 107.  , 107.  , 107.  , 107.  , 107.  , 107.  , 108.  ,
#        108.  , 108.  , 109.  , 109.  , 109.  , 110.  , 110.  , 110.  ,
#        110.  , 111.  , 111.  , 112.15, 113.  , 113.  , 113.  , 113.  ,
#        114.  , 114.  , 114.  , 114.  , 114.7 , 115.  , 115.  , 115.  ,
#        116.  , 116.  , 116.  , 116.35, 117.  , 118.  , 118.  , 119.  ,
#        120.  , 120.  ])

# %%
#calculating the max of children
np.max(dataframe.children)
# Out:
# 9

# %%
#calculating the min of health1
np.min(dataframe.health1)
# Out:
# -2.264

# %%
#calculating the range for health1
np.ptp(dataframe.health1)
# Out:
# 9.481

# %%
#calculating the interquartile range for children
np.quantile(dataframe.children, 0.75) - np.quantile(dataframe.children, 0.25)
# Out:
# 2.0

# %%
#calculating the interdecile range for children
np.quantile(dataframe.children, 0.9) - np.quantile(dataframe.children, 0.1)
# Out:
# 3.0

# %%
#calculating the mean difference for heath1
np.mean(np.diff(dataframe.health1))
# Out:
# -0.0026211055276381904

# %%
#calculating the variance for heath2
np.var(dataframe.health2)
# Out:
# 0.5473843269060176

# %%
#calculating the standard deviation for income
np.std(dataframe.income)
# Out:
# 3.6287258506577857

# %%
#calculating the mean deviation for exposure
np.mean(np.abs(dataframe.exposure- np.mean(dataframe.exposure)))
# Out:
# 7.3105675714907825

# %%
#calculating the skewness for income
from scipy.stats import skew
skew(dataframe.income)
# Out:
# 1.0441760018019348

# %%
#calculating the kurtosis for children
from scipy.stats import kurtosis
kurtosis(dataframe.children)
# Out:
# 1.2187263504311314

# %%
#calculating frequency distribution for children
dataframe.children.value_counts()
# Out:
# children
# 0    423
# 1    199
# 2    163
# 3    117
# 4     59
# 5     21
# 6      8
# 7      5
# 9      1
# Name: count, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Data for age
age_data = dataframe['age']

# Create a histogram
plt.figure(figsize=(10, 6))
counts, bin_edges, _ = plt.hist(age_data, bins=10, color='blue', edgecolor='black', alpha=0.6, label='Histogram')

# Calculate the midpoints of the bins for the frequency polygon
bin_midpoints = (bin_edges[:-1] + bin_edges[1:]) / 2

# Plot frequency polygon
plt.plot(bin_midpoints, counts, color='red', marker='o', linestyle='-', lw=2, label='Frequency Polygon')

# Adding labels and title
plt.title('Histogram and Frequency Polygon for Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for age
age_data = dataframe['age']

# Create a relative frequency histogram
plt.figure(figsize=(10, 6))

# Plot histogram with density=True to plot relative frequencies
counts, bin_edges, _ = plt.hist(age_data, bins=10, density=True, color='green', edgecolor='black', alpha=0.6, label='Relative Frequency Histogram')

# Adding labels and title
plt.title('Relative Frequency Histogram for Age')
plt.xlabel('Age')
plt.ylabel('Relative Frequency')

# Show the plot
plt.show()

# %%
#Relative frequency Distribution
import pandas as pd
import numpy as np

# Data for age
age_data = dataframe['age']

# Create a frequency distribution (counts per bin)
counts, bin_edges = np.histogram(age_data, bins=10)

# Calculate the total number of data points
total_count = len(age_data)

# Calculate relative frequencies by dividing each bin's count by the total number of data points
relative_frequencies = counts / total_count

# Create a DataFrame to display the bins and corresponding relative frequencies
relative_freq_distribution = pd.DataFrame({
    'Bin Range': pd.IntervalIndex.from_breaks(bin_edges),
    'Relative Frequency': relative_frequencies
})

# Display the relative frequency distribution
relative_freq_distribution
# Out:
#                     Bin Range  Relative Frequency
# 0                (16.0, 24.9]            0.125502
# 1                (24.9, 33.8]            0.194779
# 2                (33.8, 42.7]            0.117470
# 3                (42.7, 51.6]            0.030120
# 4                (51.6, 60.5]            0.018072
# 5                (60.5, 69.4]            0.071285
# 6   (69.4, 78.30000000000001]            0.204819
# 7   (78.30000000000001, 87.2]            0.178715
# 8   (87.2, 96.10000000000001]            0.057229
# 9  (96.10000000000001, 105.0]            0.002008

# %%
#Cumulative frequency Distribution / Ogives
import pandas as pd
import numpy as np

# Data for age
age_data = dataframe['age']

# Create a frequency distribution (counts per bin)
counts, bin_edges = np.histogram(age_data, bins=10)

# Calculate cumulative frequencies
cumulative_frequencies = np.cumsum(counts)

# Create a DataFrame to display the bins and corresponding cumulative frequencies
cumulative_freq_distribution = pd.DataFrame({
    'Bin Range': pd.IntervalIndex.from_breaks(bin_edges),
    'Cumulative Frequency': cumulative_frequencies
})

# Display the cumulative frequency distribution
cumulative_freq_distribution
# Out:
#                     Bin Range  Cumulative Frequency
# 0                (16.0, 24.9]                   125
# 1                (24.9, 33.8]                   319
# 2                (33.8, 42.7]                   436
# 3                (42.7, 51.6]                   466
# 4                (51.6, 60.5]                   484
# 5                (60.5, 69.4]                   555
# 6   (69.4, 78.30000000000001]                   759
# 7   (78.30000000000001, 87.2]                   937
# 8   (87.2, 96.10000000000001]                   994
# 9  (96.10000000000001, 105.0]                   996

# %%
# Previous calculations for frequency, relative frequency, and cumulative frequency
counts, bin_edges = np.histogram(age_data, bins=10)
total_count = len(age_data)
relative_frequencies = counts / total_count
cumulative_frequencies = np.cumsum(counts)

# Plotting the Ogive (Cumulative Frequency) graph using the previously calculated data
plt.figure(figsize=(10, 6))

# Plot cumulative frequency against the bin edges
plt.plot(bin_edges[1:], cumulative_frequencies, marker='o', color='blue', label='Cumulative Frequency')

# Plot relative frequency for reference
plt.plot(bin_edges[1:], relative_frequencies.cumsum(), marker='x', linestyle='--', color='red', label='Relative Frequency')

# Adding labels and title
plt.title('Ogive (Cumulative and Relative Frequency Graph) for Age')
plt.xlabel('Age Range')
plt.ylabel('Frequency')
plt.grid(True)

# Display legend
plt.legend()

# Show the plot
plt.show()

# %%
#Cummulative frequency histogram




# Frequency distribution and cumulative frequency calculations
counts, bin_edges = np.histogram(age_data, bins=10)
cumulative_frequencies = np.cumsum(counts)

# Plotting the Cumulative Frequency Histogram
plt.figure(figsize=(10, 6))

# Plot histogram with cumulative frequencies
plt.hist(age_data, bins=10, cumulative=True, color='green', edgecolor='black', alpha=0.7, label='Cumulative Frequency Histogram')

# Adding labels and title
plt.title('Cumulative Frequency Histogram for Age')
plt.xlabel('Age Range')
plt.ylabel('Cumulative Frequency')
plt.grid(True)

# Show the plot
plt.legend()
plt.show()

# %%
# Dispersion Box Plots for consumption
# Plotting a boxplot for the 'consumption' column to show dispersion
plt.figure(figsize=(8, 6))

# Creating a box plot for 'consumption'
plt.boxplot(dataframe['health1'])

# Adding titles and labels
plt.title('Box Plot for heath1')
plt.ylabel('heath1')

# Display the plot
plt.show()

# %%
# Pie chart for children_and_marriage

income_by_gender = dataframe.groupby('gender')['income'].sum()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(income_by_gender, labels=income_y_gender.index, autopct='%1.1f%%', startangle=90)
plt.title('Married and having children')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Create a stacked bar plot
plt.figure(figsize=(10, 6))
sns.countplot(data=dataframe, x='visits', hue='children', dodge=False)

# Adding titles and labels
plt.title(" Stacked Bar Plot of visits vs children")
plt.xlabel("visits")
plt.ylabel("children")
plt.legend(title='visits')
plt.show()

# %%
# Create contingency table for categorial -categorial
contingency_table1 = pd.crosstab(dataframe['ethnicity'], dataframe['program'])
print(contingency_table1)
# Out:
# program    afdc  ssi
# ethnicity
# cauc        326  365
# other       159  146

# %%
# Create contingency table for numerical -numerical
contingency_table3 = pd.crosstab(pd.cut(dataframe['age'], bins=3), pd.cut(dataframe['income'], bins=3))
print(contingency_table3)
# Out:
# income            (0.483, 6.167]  (6.167, 11.833]  (11.833, 17.5]
# age
# (15.911, 45.667]             180              228              37
# (45.667, 75.333]             117               97              32
# (75.333, 105.0]              168              100              37

# %%
# Create contingency table for numerical -categorical
c3 = dataframe.groupby(['ethnicity'])['income'].value_counts().unstack()
c3
# Out:
# income     0.500   1.500   2.500   4.000   6.000   6.180   6.375   6.850   \
# ethnicity
# cauc          7.0     4.0    11.0    50.0   278.0     2.0     NaN     NaN
# other         1.0     6.0     8.0    15.0    85.0     NaN     1.0     1.0
#
# income     6.931   7.040   ...  10.204  10.264  10.444  10.750  11.500  \
# ethnicity                  ...
# cauc          NaN     3.0  ...     2.0     NaN     NaN     NaN    72.0
# other         2.0     NaN  ...     NaN     3.0     1.0     2.0    35.0
#
# income     12.150  12.262  13.375  14.500  17.500
# ethnicity
# cauc          NaN     NaN     NaN    23.0    40.0
# other         1.0     1.0     1.0    11.0    29.0
#
# [2 rows x 45 columns]

# %%
 #Create a 3 way contingency table for the Q3.
 import pandas as pd

# Assuming you have a DataFrame named 'titanic_df' with columns 'Survived', 'Sex', and 'Fare'
table3way = pd.crosstab([dataframe['exposure'], dataframe['gender']], dataframe['income'])

print(table3way)
# Out:
# income           0.500   1.500   2.500   4.000   6.000   6.180   6.375   \
# exposure gender
# 32       female       0       0       0       0       0       0       0
# 39       female       0       0       0       0       1       0       0
# 52       female       0       0       0       0       1       0       0
# 69       male         0       0       0       0       0       0       0
# 71       male         0       0       0       0       0       0       0
# ...                 ...     ...     ...     ...     ...     ...     ...
# 118      male         0       0       0       0       0       0       0
# 119      female       1       0       0       0       3       0       0
#          male         0       0       0       0       1       0       0
# 120      female       0       0       0       2       4       0       0
#          male         0       0       0       1       1       0       0
#
# income           6.850   6.931   7.040   ...  10.204  10.264  10.444  10.750  \
# ...

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency



# Row profile
row_profile = contingency_table1.div(contingency_table1.sum(axis=1), axis=0)
print(row_profile)
# Out:
# program        afdc       ssi
# ethnicity
# cauc       0.471780  0.528220
# other      0.521311  0.478689

# %%
# Column profile dataset
column_profile = contingency_table1.div(contingency_table1.sum(axis=0), axis=1)
print(column_profile)
# Out:
# program        afdc       ssi
# ethnicity
# cauc       0.672165  0.714286
# other      0.327835  0.285714

# %%
#Relative frequency
total_sum = contingency_table1.sum().sum()
contingency_table1 / total_sum
# Out:
# program        afdc       ssi
# ethnicity
# cauc       0.327309  0.366466
# other      0.159639  0.146586

# %%
#Chi-square dataset for c1
from scipy.stats import chi2_contingency
chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table1)
print(chi2_stat)
print(p_value)
print(dof)
print(expected)
# Out:
# 1.884425448332163
# 0.16983201799595382
# 1
# [[336.48092369 354.51907631]
#  [148.51907631 156.48092369]]

# %%
#Display the scatter plot using ggplot.
sns.scatterplot(x='exposure', y='income', data=dataframe)
plt.show()

# %%
#the scatter plot for 3 variables , health1 , health2 and age
x_column = 'age'
y_column = 'exposure'
z_column = 'income'

# Create a 3D figure and axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the scatter plot
ax.scatter(dataframe[x_column], dataframe[y_column], dataframe[z_column])

# Set labels and title
ax.set_xlabel(x_column)
ax.set_ylabel(y_column)
ax.set_zlabel(z_column)
plt.title('3D Scatter Plot')

plt.show()
